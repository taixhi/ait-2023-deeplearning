# %% [markdown]
# <a href="https://colab.research.google.com/github/taixhi/ait-2023-deeplearning/blob/main/DeepLearning_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://news.artnet.com/app/news-upload/2019/01/Cat-Photog-Feat-256x256.jpg -O cat.jpg
# Out:
# --2023-02-16 08:09:57--  https://news.artnet.com/app/news-upload/2019/01/Cat-Photog-Feat-256x256.jpg
# Resolving news.artnet.com (news.artnet.com)... 104.18.22.72, 104.18.23.72
# Connecting to news.artnet.com (news.artnet.com)|104.18.22.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35160 (34K) [image/jpeg]
# Saving to: ‘cat.jpg’
#
# cat.jpg             100%[===================>]  34.34K  --.-KB/s    in 0.001s
#
# 2023-02-16 08:09:57 (52.0 MB/s) - ‘cat.jpg’ saved [35160/35160]

# %%
from matplotlib import image
img = image.imread('cat.jpg')
# Out:
# uint8
# (256, 256, 3)

# %%
import numpy as np
data = np.array(img)

# %%
data[:30,:30,:] = 0

# %%
from matplotlib import pyplot
pyplot.imshow(data)
